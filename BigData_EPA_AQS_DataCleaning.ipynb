# %%
# !pip install git+git://github.com/VIDA-NYU/openclean.git
from openclean.pipeline import stream
# Out:
# Collecting git+git://github.com/VIDA-NYU/openclean.git
#   Cloning git://github.com/VIDA-NYU/openclean.git to /private/var/folders/5j/3dzb0k4d1cl2gz3w87fxpf1m0000gn/T/pip-req-build-8_e995j3
#   Running command git clone -q git://github.com/VIDA-NYU/openclean.git /private/var/folders/5j/3dzb0k4d1cl2gz3w87fxpf1m0000gn/T/pip-req-build-8_e995j3
#   Running command git submodule update --init --recursive -q
# Requirement already satisfied: openclean-core==0.3.0 in ./venv_project/lib/python3.9/site-packages (from openclean==0.1.0) (0.3.0)
# Requirement already satisfied: jellyfish in ./venv_project/lib/python3.9/site-packages (from openclean-core==0.3.0->openclean==0.1.0) (0.8.2)
# Requirement already satisfied: scipy in ./venv_project/lib/python3.9/site-packages (from openclean-core==0.3.0->openclean==0.1.0) (1.6.2)
# Requirement already satisfied: future in ./venv_project/lib/python3.9/site-packages (from openclean-core==0.3.0->openclean==0.1.0) (0.18.2)
# Requirement already satisfied: scikit-learn in ./venv_project/lib/python3.9/site-packages (from openclean-core==0.3.0->openclean==0.1.0) (0.23.2)
# Requirement already satisfied: dill in ./venv_project/lib/python3.9/site-packages (from openclean-core==0.3.0->openclean==0.1.0) (0.3.3)
# Requirement already satisfied: histore==0.3.1 in ./venv_project/lib/python3.9/site-packages (from openclean-core==0.3.0->openclean==0.1.0) (0.3.1)
# Requirement already satisfied: pandas>=1.0.0 in ./venv_project/lib/python3.9/site-packages (from openclean-core==0.3.0->openclean==0.1.0) (1.2.3)
# Requirement already satisfied: jsonschema>=3.2.0 in ./venv_project/lib/python3.9/site-packages (from openclean-core==0.3.0->openclean==0.1.0) (3.2.0)
# Requirement already satisfied: requests in ./venv_project/lib/python3.9/site-packages (from openclean-core==0.3.0->openclean==0.1.0) (2.25.1)
# Requirement already satisfied: flowserv-core>=0.8.0 in ./venv_project/lib/python3.9/site-packages (from openclean-core==0.3.0->openclean==0.1.0) (0.8.0)
# Requirement already satisfied: appdirs>=1.4.4 in ./venv_project/lib/python3.9/site-packages (from openclean-core==0.3.0->openclean==0.1.0) (1.4.4)
# Requirement already satisfied: refdata>=0.2.0 in ./venv_project/lib/python3.9/site-packages (from openclean-core==0.3.0->openclean==0.1.0) (0.2.0)
# Requirement already satisfied: python-dateutil in ./venv_project/lib/python3.9/site-packages (from openclean-core==0.3.0->openclean==0.1.0) (2.8.1)
# Requirement already satisfied: SQLAlchemy>=1.3.18 in ./venv_project/lib/python3.9/site-packages (from histore==0.3.1->openclean-core==0.3.0->openclean==0.1.0) (1.4.3)
# Requirement already satisfied: psutil in ./venv_project/lib/python3.9/site-packages (from histore==0.3.1->openclean-core==0.3.0->openclean==0.1.0) (5.8.0)
# Requirement already satisfied: Click>=7.0 in ./venv_project/lib/python3.9/site-packages (from histore==0.3.1->openclean-core==0.3.0->openclean==0.1.0) (7.1.2)
# Requirement already satisfied: pyyaml in ./venv_project/lib/python3.9/site-packages (from histore==0.3.1->openclean-core==0.3.0->openclean==0.1.0) (5.4.1)
# Requirement already satisfied: gitpython in ./venv_project/lib/python3.9/site-packages (from flowserv-core>=0.8.0->openclean-core==0.3.0->openclean==0.1.0) (3.1.14)
# Requirement already satisfied: passlib in ./venv_project/lib/python3.9/site-packages (from flowserv-core>=0.8.0->openclean-core==0.3.0->openclean==0.1.0) (1.7.4)
# Requirement already satisfied: attrs>=17.4.0 in ./venv_project/lib/python3.9/site-packages (from jsonschema>=3.2.0->openclean-core==0.3.0->openclean==0.1.0) (20.3.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in ./venv_project/lib/python3.9/site-packages (from jsonschema>=3.2.0->openclean-core==0.3.0->openclean==0.1.0) (0.17.3)
# Requirement already satisfied: setuptools in ./venv_project/lib/python3.9/site-packages (from jsonschema>=3.2.0->openclean-core==0.3.0->openclean==0.1.0) (54.1.2)
# Requirement already satisfied: six>=1.11.0 in ./venv_project/lib/python3.9/site-packages (from jsonschema>=3.2.0->openclean-core==0.3.0->openclean==0.1.0) (1.15.0)
# Requirement already satisfied: pytz>=2017.3 in ./venv_project/lib/python3.9/site-packages (from pandas>=1.0.0->openclean-core==0.3.0->openclean==0.1.0) (2021.1)
# Requirement already satisfied: numpy>=1.16.5 in ./venv_project/lib/python3.9/site-packages (from pandas>=1.0.0->openclean-core==0.3.0->openclean==0.1.0) (1.20.2)
# Requirement already satisfied: pooch>=1.3.0 in ./venv_project/lib/python3.9/site-packages (from refdata>=0.2.0->openclean-core==0.3.0->openclean==0.1.0) (1.3.0)
# Requirement already satisfied: tableprint in ./venv_project/lib/python3.9/site-packages (from refdata>=0.2.0->openclean-core==0.3.0->openclean==0.1.0) (0.9.1)
# Requirement already satisfied: datasize>=1.0.0 in ./venv_project/lib/python3.9/site-packages (from refdata>=0.2.0->openclean-core==0.3.0->openclean==0.1.0) (1.0.0)
# Requirement already satisfied: packaging in ./venv_project/lib/python3.9/site-packages (from pooch>=1.3.0->refdata>=0.2.0->openclean-core==0.3.0->openclean==0.1.0) (20.9)
# Requirement already satisfied: greenlet!=0.4.17 in ./venv_project/lib/python3.9/site-packages (from SQLAlchemy>=1.3.18->histore==0.3.1->openclean-core==0.3.0->openclean==0.1.0) (1.0.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in ./venv_project/lib/python3.9/site-packages (from gitpython->flowserv-core>=0.8.0->openclean-core==0.3.0->openclean==0.1.0) (4.0.7)
# Requirement already satisfied: smmap<5,>=3.0.1 in ./venv_project/lib/python3.9/site-packages (from gitdb<5,>=4.0.1->gitpython->flowserv-core>=0.8.0->openclean-core==0.3.0->openclean==0.1.0) (4.0.0)
# Requirement already satisfied: pyparsing>=2.0.2 in ./venv_project/lib/python3.9/site-packages (from packaging->pooch>=1.3.0->refdata>=0.2.0->openclean-core==0.3.0->openclean==0.1.0) (2.4.7)
# Requirement already satisfied: idna<3,>=2.5 in ./venv_project/lib/python3.9/site-packages (from requests->openclean-core==0.3.0->openclean==0.1.0) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in ./venv_project/lib/python3.9/site-packages (from requests->openclean-core==0.3.0->openclean==0.1.0) (1.26.4)
# Requirement already satisfied: chardet<5,>=3.0.2 in ./venv_project/lib/python3.9/site-packages (from requests->openclean-core==0.3.0->openclean==0.1.0) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./venv_project/lib/python3.9/site-packages (from requests->openclean-core==0.3.0->openclean==0.1.0) (2020.12.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./venv_project/lib/python3.9/site-packages (from scikit-learn->openclean-core==0.3.0->openclean==0.1.0) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in ./venv_project/lib/python3.9/site-packages (from scikit-learn->openclean-core==0.3.0->openclean==0.1.0) (1.0.1)
# Requirement already satisfied: wcwidth in ./venv_project/lib/python3.9/site-packages (from tableprint->refdata>=0.2.0->openclean-core==0.3.0->openclean==0.1.0) (0.2.5)

# %%
# Import the data using the EPA_AQS Utility
# install requirements
# !pip install -r data_collection/EPA_AQS_Air_Data/requirements.txt
# %run ./data_collection/EPA_AQS_Air_Data/epa_air.py
# Out:
# Requirement already satisfied: requests in ./venv_project/lib/python3.9/site-packages (from -r data_collection/EPA_AQS_Air_Data/requirements.txt (line 1)) (2.25.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in ./venv_project/lib/python3.9/site-packages (from requests->-r data_collection/EPA_AQS_Air_Data/requirements.txt (line 1)) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in ./venv_project/lib/python3.9/site-packages (from requests->-r data_collection/EPA_AQS_Air_Data/requirements.txt (line 1)) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in ./venv_project/lib/python3.9/site-packages (from requests->-r data_collection/EPA_AQS_Air_Data/requirements.txt (line 1)) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in ./venv_project/lib/python3.9/site-packages (from requests->-r data_collection/EPA_AQS_Air_Data/requirements.txt (line 1)) (1.26.4)
# Retrieved parameter list.
# [{'code': '42101', 'value_represented': 'Carbon monoxide'}, {'code': '42401', 'value_represented': 'Sulfur dioxide'}, {'code': '42602', 'value_represented': 'Nitrogen dioxide (NO2)'}, {'code': '44201', 'value_represented': 'Ozone'}, {'code': '81102', 'value_represented': 'PM10 Total 0-10um STP'}, {'code': '88101', 'value_represented': 'PM2.5 - Local Conditions'}, {'code': '88502', 'value_represented': 'Acceptable PM2.5 AQI & Speciation Mass'}]
# write complete
# write complete
# No rows retrieved for Sulfur dioxide and year 2019
# No rows retrieved for Sulfur dioxide and year 2020
# No rows retrieved for Nitrogen dioxide (NO2) and year 2019
# No rows retrieved for Nitrogen dioxide (NO2) and year 2020
# write complete
# write complete
# write complete
# write complete
# write complete
# write complete
# write complete
# write complete
# Finished

# %%
# read the csv into the stream
datafile = "epa_aqs_air_AQI-POLLUTANTS_2019-2020.csv"
ds = stream(datafile)

#Print the first ten rows of the dataset
ds.head()
# Out:
#   state_code county_code site_number parameter_code poc  latitude  longitude  \
# 0         36         061        0135          42101   1  40.81976  -73.94825
# 1         36         061        0135          42101   1  40.81976  -73.94825
# 2         36         061        0135          42101   1  40.81976  -73.94825
# 3         36         061        0135          42101   1  40.81976  -73.94825
# 4         36         061        0135          42101   1  40.81976  -73.94825
# 5         36         061        0135          42101   1  40.81976  -73.94825
# 6         36         061        0135          42101   1  40.81976  -73.94825
# 7         36         061        0135          42101   1  40.81976  -73.94825
# 8         36         061        0135          42101   1  40.81976  -73.94825
# 9         36         061        0135          42101   1  40.81976  -73.94825
#
#    datum        parameter        sample_duration  ... method_code  \
# 0  WGS84  Carbon monoxide                 1 HOUR  ...         554
# 1  WGS84  Carbon monoxide  8-HR RUN AVG END HOUR  ...         554
# 2  WGS84  Carbon monoxide                 1 HOUR  ...         554
# 3  WGS84  Carbon monoxide  8-HR RUN AVG END HOUR  ...         554
# 4  WGS84  Carbon monoxide                 1 HOUR  ...         554
# 5  WGS84  Carbon monoxide  8-HR RUN AVG END HOUR  ...         554
# 6  WGS84  Carbon monoxide                 1 HOUR  ...         554
# 7  WGS84  Carbon monoxide  8-HR RUN AVG END HOUR  ...         554
# 8  WGS84  Carbon monoxide                 1 HOUR  ...         554
# 9  WGS84  Carbon monoxide  8-HR RUN AVG END HOUR  ...         554
#
#                                               method local_site_name  \
# 0  INSTRUMENTAL - Gas Filter Correlation Thermo E...            CCNY
# 1  INSTRUMENTAL - Gas Filter Correlation Thermo E...            CCNY
# 2  INSTRUMENTAL - Gas Filter Correlation Thermo E...            CCNY
# 3  INSTRUMENTAL - Gas Filter Correlation Thermo E...            CCNY
# 4  INSTRUMENTAL - Gas Filter Correlation Thermo E...            CCNY
# 5  INSTRUMENTAL - Gas Filter Correlation Thermo E...            CCNY
# 6  INSTRUMENTAL - Gas Filter Correlation Thermo E...            CCNY
# 7  INSTRUMENTAL - Gas Filter Correlation Thermo E...            CCNY
# 8  INSTRUMENTAL - Gas Filter Correlation Thermo E...            CCNY
# 9  INSTRUMENTAL - Gas Filter Correlation Thermo E...            CCNY
#
#          site_address     state    county      city cbsa_code  \
# 0  160 CONVENT AVENUE  New York  New York  New York     35620
# 1  160 CONVENT AVENUE  New York  New York  New York     35620
# 2  160 CONVENT AVENUE  New York  New York  New York     35620
# 3  160 CONVENT AVENUE  New York  New York  New York     35620
# 4  160 CONVENT AVENUE  New York  New York  New York     35620
# 5  160 CONVENT AVENUE  New York  New York  New York     35620
# 6  160 CONVENT AVENUE  New York  New York  New York     35620
# 7  160 CONVENT AVENUE  New York  New York  New York     35620
# 8  160 CONVENT AVENUE  New York  New York  New York     35620
# 9  160 CONVENT AVENUE  New York  New York  New York     35620
#
#                                     cbsa date_of_last_change
# 0  New York-Newark-Jersey City, NY-NJ-PA          2021-01-21
# 1  New York-Newark-Jersey City, NY-NJ-PA          2021-01-21
# 2  New York-Newark-Jersey City, NY-NJ-PA          2021-01-21
# 3  New York-Newark-Jersey City, NY-NJ-PA          2021-01-21
# 4  New York-Newark-Jersey City, NY-NJ-PA          2021-01-21
# 5  New York-Newark-Jersey City, NY-NJ-PA          2021-01-21
# 6  New York-Newark-Jersey City, NY-NJ-PA          2021-01-21
# 7  New York-Newark-Jersey City, NY-NJ-PA          2021-01-21
# 8  New York-Newark-Jersey City, NY-NJ-PA          2021-01-21
# 9  New York-Newark-Jersey City, NY-NJ-PA          2021-01-21
#
# [10 rows x 31 columns]

# %%
# Profile the rows using the default profiler
from openclean.profiling.column import DefaultColumnProfiler

profiles = ds.profile(default_profiler=DefaultColumnProfiler)

# %%
# Print overview of the profiling results
profiles.stats()
# Out:
#                      total  empty  distinct  uniqueness    entropy
# state_code            9440      0         1    0.000106   0.000000
# county_code           9440      0         1    0.000106   0.000000
# site_number           9440      0         5    0.000530   1.939192
# parameter_code        9440      0         5    0.000530   1.860861
# poc                   9440      0         3    0.000318   1.190731
# latitude              9440      0         5    0.000530   1.939192
# longitude             9440      0         5    0.000530   1.939192
# datum                 9440      0         1    0.000106   0.000000
# parameter             9440      0         5    0.000530   1.860861
# sample_duration       9440      0         5    0.000530   2.133187
# pollutant_standard    9440   3850        11    0.001968   3.338677
# date_local            9440      0       731    0.077436   9.391783
# units_of_measure      9440      0         3    0.000318   1.013681
# event_type            9440      0         1    0.000106   0.000000
# observation_count     9440      0        24    0.002542   1.812447
# observation_percent   9440      0        30    0.003178   0.618610
# validity_indicator    9440      0         2    0.000212   0.102903
# arithmetic_mean       9440      0      3423    0.362606  10.505563
# first_max_value       9440      0       679    0.071928   8.109239
# first_max_hour        9440      0        24    0.002542   3.639585
# aqi                   9440   3033        85    0.013267   5.833133
# method_code           9440      0         5    0.000530   1.860861
# method                9440      0         5    0.000530   1.860861
# local_site_name       9440      0         5    0.000530   1.939192
# site_address          9440      0         5    0.000530   1.939192
# state                 9440      0         1    0.000106   0.000000
# county                9440      0         1    0.000106   0.000000
# city                  9440      0         1    0.000106   0.000000
# cbsa_code             9440      0         1    0.000106   0.000000
# cbsa                  9440      0         1    0.000106   0.000000
# date_of_last_change   9440      0        11    0.001165   2.941392
